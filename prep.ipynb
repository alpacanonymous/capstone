# %% [markdown]
# Includes four major pollutants (Nitrogen Dioxide, Sulphur Dioxide, Carbon Monoxide and Ozone).
#
# - State Code : The code allocated by US EPA to each state
# - County code : The code of counties in a specific state allocated by US EPA
# - Site Num : The site number in a specific county allocated by US EPA
# - Address: Address of the monitoring site
# - State : State of monitoring site
# - County : County of monitoring site
# - City : City of the monitoring site
# - Date Local : Date of monitoring
#
#
# The four pollutants (NO2, O3, SO2 and O3) each has 5 specific columns. For instance, for NO2:
#
# - NO2 Units : The units measured for NO2
# - NO2 Mean : The arithmetic mean of concentration of NO2 within a given day
# - NO2 AQI : The calculated air quality index of NO2 within a given day
# - NO2 1st Max Value : The maximum value obtained for NO2 concentration in a given day
# - NO2 1st Max Hour : The hour when the maximum NO2 concentration was recorded in a given day

# %%
# Import libraries
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import data
df = pd.read_csv('data/pollution_us_2000_2016.csv')

# %%
df.sample()
# Out:
#          Unnamed: 0  State Code  County Code  Site Num           Address  \
# 1219059       17429           6           23      1004  717 SOUTH AVENUE
#
#               State    County    City  Date Local          NO2 Units  ...  \
# 1219059  California  Humboldt  Eureka  2012-09-28  Parts per billion  ...
#
#                  SO2 Units  SO2 Mean  SO2 1st Max Value  SO2 1st Max Hour  \
# 1219059  Parts per billion -0.057143                0.0                 2
#
#         SO2 AQI           CO Units  CO Mean  CO 1st Max Value  \
# 1219059     NaN  Parts per million   0.3625               0.4
#
#          CO 1st Max Hour CO AQI
# 1219059                1    5.0
#
# [1 rows x 29 columns]

# %%
df.loc[(df['County'] == 'Los Angeles')]
# Out:
#          Unnamed: 0  State Code  County Code  Site Num  \
# 10666         10666           6           37      1002
# 10667         10667           6           37      1002
# 10668         10668           6           37      1002
# 10669         10669           6           37      1002
# 10670         10670           6           37      1002
# ...             ...         ...          ...       ...
# 1619794       23793           6           37      5005
# 1619795       23794           6           37      5005
# 1619796       23795           6           37      5005
# 1619797       23796           6           37      5005
# 1619798       23797           6           37      5005
#
#                              Address       State       County         City  \
# 10666      228 W. PALM AVE., BURBANK  California  Los Angeles      Burbank
# 10667      228 W. PALM AVE., BURBANK  California  Los Angeles      Burbank
# 10668      228 W. PALM AVE., BURBANK  California  Los Angeles      Burbank
# 10669      228 W. PALM AVE., BURBANK  California  Los Angeles      Burbank
# 10670      228 W. PALM AVE., BURBANK  California  Los Angeles      Burbank
# ...                              ...         ...          ...          ...
# 1619794  7201 W. WESTCHESTER PARKWAY  California  Los Angeles  Los Angeles
# 1619795  7201 W. WESTCHESTER PARKWAY  California  Los Angeles  Los Angeles
# 1619796  7201 W. WESTCHESTER PARKWAY  California  Los Angeles  Los Angeles
# 1619797  7201 W. WESTCHESTER PARKWAY  California  Los Angeles  Los Angeles
# 1619798  7201 W. WESTCHESTER PARKWAY  California  Los Angeles  Los Angeles
#
#          Date Local          NO2 Units  ...          SO2 Units  SO2 Mean  \
# 10666    2000-01-01  Parts per billion  ...  Parts per billion  0.000000
# 10667    2000-01-01  Parts per billion  ...  Parts per billion  0.000000
# 10668    2000-01-01  Parts per billion  ...  Parts per billion  0.000000
# 10669    2000-01-01  Parts per billion  ...  Parts per billion  0.000000
# 10670    2000-01-02  Parts per billion  ...  Parts per billion  0.000000
# ...             ...                ...  ...                ...       ...
# 1619794  2015-12-30  Parts per billion  ...  Parts per billion  0.785714
# 1619795  2015-12-31  Parts per billion  ...  Parts per billion  0.565217
# 1619796  2015-12-31  Parts per billion  ...  Parts per billion  0.565217
# 1619797  2015-12-31  Parts per billion  ...  Parts per billion  0.557143
# 1619798  2015-12-31  Parts per billion  ...  Parts per billion  0.557143
#
#          SO2 1st Max Value  SO2 1st Max Hour SO2 AQI           CO Units  \
# 10666                  0.0                 0     0.0  Parts per million
# 10667                  0.0                 0     0.0  Parts per million
# 10668                  0.0                 2     NaN  Parts per million
# 10669                  0.0                 2     NaN  Parts per million
# 10670                  0.0                 0     0.0  Parts per million
# ...                    ...               ...     ...                ...
# 1619794                1.2                11     NaN  Parts per million
# 1619795                0.9                 0     0.0  Parts per million
# 1619796                0.9                 0     0.0  Parts per million
# 1619797                0.8                 2     NaN  Parts per million
# 1619798                0.8                 2     NaN  Parts per million
#
#           CO Mean  CO 1st Max Value  CO 1st Max Hour CO AQI
# 10666    1.360870               3.7                2    NaN
# 10667    1.300000               3.0                6   34.0
# 10668    1.360870               3.7                2    NaN
# 10669    1.300000               3.0                6   34.0
# 10670    0.373913               1.0                1    NaN
# ...           ...               ...              ...    ...
# 1619794  0.483333               0.8                4    9.0
# 1619795  0.382609               1.1                0    NaN
# 1619796  0.425000               0.7                3    8.0
# 1619797  0.382609               1.1                0    NaN
# 1619798  0.425000               0.7                3    8.0
#
# [93381 rows x 29 columns]

# %%
df.loc[(df['County'] == 'Los Angeles') & (df['State'] == 'California')]
# Out:
#          Unnamed: 0  State Code  County Code  Site Num  \
# 10666         10666           6           37      1002
# 10667         10667           6           37      1002
# 10668         10668           6           37      1002
# 10669         10669           6           37      1002
# 10670         10670           6           37      1002
# ...             ...         ...          ...       ...
# 1619794       23793           6           37      5005
# 1619795       23794           6           37      5005
# 1619796       23795           6           37      5005
# 1619797       23796           6           37      5005
# 1619798       23797           6           37      5005
#
#                              Address       State       County         City  \
# 10666      228 W. PALM AVE., BURBANK  California  Los Angeles      Burbank
# 10667      228 W. PALM AVE., BURBANK  California  Los Angeles      Burbank
# 10668      228 W. PALM AVE., BURBANK  California  Los Angeles      Burbank
# 10669      228 W. PALM AVE., BURBANK  California  Los Angeles      Burbank
# 10670      228 W. PALM AVE., BURBANK  California  Los Angeles      Burbank
# ...                              ...         ...          ...          ...
# 1619794  7201 W. WESTCHESTER PARKWAY  California  Los Angeles  Los Angeles
# 1619795  7201 W. WESTCHESTER PARKWAY  California  Los Angeles  Los Angeles
# 1619796  7201 W. WESTCHESTER PARKWAY  California  Los Angeles  Los Angeles
# 1619797  7201 W. WESTCHESTER PARKWAY  California  Los Angeles  Los Angeles
# 1619798  7201 W. WESTCHESTER PARKWAY  California  Los Angeles  Los Angeles
#
#          Date Local          NO2 Units  ...          SO2 Units  SO2 Mean  \
# 10666    2000-01-01  Parts per billion  ...  Parts per billion  0.000000
# 10667    2000-01-01  Parts per billion  ...  Parts per billion  0.000000
# 10668    2000-01-01  Parts per billion  ...  Parts per billion  0.000000
# 10669    2000-01-01  Parts per billion  ...  Parts per billion  0.000000
# 10670    2000-01-02  Parts per billion  ...  Parts per billion  0.000000
# ...             ...                ...  ...                ...       ...
# 1619794  2015-12-30  Parts per billion  ...  Parts per billion  0.785714
# 1619795  2015-12-31  Parts per billion  ...  Parts per billion  0.565217
# 1619796  2015-12-31  Parts per billion  ...  Parts per billion  0.565217
# 1619797  2015-12-31  Parts per billion  ...  Parts per billion  0.557143
# 1619798  2015-12-31  Parts per billion  ...  Parts per billion  0.557143
#
#          SO2 1st Max Value  SO2 1st Max Hour SO2 AQI           CO Units  \
# 10666                  0.0                 0     0.0  Parts per million
# 10667                  0.0                 0     0.0  Parts per million
# 10668                  0.0                 2     NaN  Parts per million
# 10669                  0.0                 2     NaN  Parts per million
# 10670                  0.0                 0     0.0  Parts per million
# ...                    ...               ...     ...                ...
# 1619794                1.2                11     NaN  Parts per million
# 1619795                0.9                 0     0.0  Parts per million
# 1619796                0.9                 0     0.0  Parts per million
# 1619797                0.8                 2     NaN  Parts per million
# 1619798                0.8                 2     NaN  Parts per million
#
#           CO Mean  CO 1st Max Value  CO 1st Max Hour CO AQI
# 10666    1.360870               3.7                2    NaN
# 10667    1.300000               3.0                6   34.0
# 10668    1.360870               3.7                2    NaN
# 10669    1.300000               3.0                6   34.0
# 10670    0.373913               1.0                1    NaN
# ...           ...               ...              ...    ...
# 1619794  0.483333               0.8                4    9.0
# 1619795  0.382609               1.1                0    NaN
# 1619796  0.425000               0.7                3    8.0
# 1619797  0.382609               1.1                0    NaN
# 1619798  0.425000               0.7                3    8.0
#
# [93381 rows x 29 columns]

# %%
df['County'].value_counts()
# Out:
# Los Angeles      93381
# Contra Costa     84010
# Santa Barbara    82998
# San Diego        51110
# Maricopa         46586
#                  ...
# Athens             908
# Haywood            904
# Kern               434
# Richland           116
# Duchesne           104
# Name: County, Length: 133, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1746661 entries, 0 to 1746660
# Data columns (total 29 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Unnamed: 0         int64
#  1   State Code         int64
#  2   County Code        int64
#  3   Site Num           int64
#  4   Address            object
#  5   State              object
#  6   County             object
#  7   City               object
#  8   Date Local         object
#  9   NO2 Units          object
#  10  NO2 Mean           float64
#  11  NO2 1st Max Value  float64
#  12  NO2 1st Max Hour   int64
#  13  NO2 AQI            int64
#  14  O3 Units           object
#  15  O3 Mean            float64
#  16  O3 1st Max Value   float64
#  17  O3 1st Max Hour    int64
#  18  O3 AQI             int64
#  19  SO2 Units          object
#  20  SO2 Mean           float64
#  21  SO2 1st Max Value  float64
#  22  SO2 1st Max Hour   int64
#  23  SO2 AQI            float64
#  24  CO Units           object
#  25  CO Mean            float64
#  26  CO 1st Max Value   float64
#  27  CO 1st Max Hour    int64
#  28  CO AQI             float64
# dtypes: float64(10), int64(10), object(9)
# memory usage: 386.5+ MB

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'State Code', 'County Code', 'Site Num', 'Address',
#        'State', 'County', 'City', 'Date Local', 'NO2 Units', 'NO2 Mean',
#        'NO2 1st Max Value', 'NO2 1st Max Hour', 'NO2 AQI', 'O3 Units',
#        'O3 Mean', 'O3 1st Max Value', 'O3 1st Max Hour', 'O3 AQI', 'SO2 Units',
#        'SO2 Mean', 'SO2 1st Max Value', 'SO2 1st Max Hour', 'SO2 AQI',
#        'CO Units', 'CO Mean', 'CO 1st Max Value', 'CO 1st Max Hour', 'CO AQI'],
#       dtype='object')

# %%
df['Unnamed: 0'].value_counts()
# Out:
# 2047      17
# 11834     17
# 1600      17
# 23115     17
# 21066     17
#           ..
# 133524     1
# 132366     1
# 134415     1
# 133448     1
# 132120     1
# Name: Unnamed: 0, Length: 134576, dtype: int64

# %%
df['Date Local'] = pd.to_datetime(df['Date Local'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1746661 entries, 0 to 1746660
# Data columns (total 29 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Unnamed: 0         int64
#  1   State Code         int64
#  2   County Code        int64
#  3   Site Num           int64
#  4   Address            object
#  5   State              object
#  6   County             object
#  7   City               object
#  8   Date Local         datetime64[ns]
#  9   NO2 Units          object
#  10  NO2 Mean           float64
#  11  NO2 1st Max Value  float64
#  12  NO2 1st Max Hour   int64
#  13  NO2 AQI            int64
#  14  O3 Units           object
#  15  O3 Mean            float64
#  16  O3 1st Max Value   float64
#  17  O3 1st Max Hour    int64
#  18  O3 AQI             int64
#  19  SO2 Units          object
#  20  SO2 Mean           float64
#  21  SO2 1st Max Value  float64
#  22  SO2 1st Max Hour   int64
#  23  SO2 AQI            float64
#  24  CO Units           object
#  25  CO Mean            float64
#  26  CO 1st Max Value   float64
#  27  CO 1st Max Hour    int64
#  28  CO AQI             float64
# dtypes: datetime64[ns](1), float64(10), int64(10), object(8)
# memory usage: 386.5+ MB

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#          Unnamed: 0  State Code  County Code  Site Num  \
# 0                 0           4           13      3002
# 1                 1           4           13      3002
# 2                 2           4           13      3002
# 3                 3           4           13      3002
# 4                 4           4           13      3002
# ...             ...         ...          ...       ...
# 1746656       24599          56           21       100
# 1746657       24600          56           21       100
# 1746658       24601          56           21       100
# 1746659       24602          56           21       100
# 1746660       24603          56           21       100
#
#                                          Address    State    County  \
# 0        1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa
# 1        1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa
# 2        1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa
# 3        1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa
# 4        1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa
# ...                                          ...      ...       ...
# 1746656    NCore - North Cheyenne Soccer Complex  Wyoming   Laramie
# 1746657    NCore - North Cheyenne Soccer Complex  Wyoming   Laramie
# 1746658    NCore - North Cheyenne Soccer Complex  Wyoming   Laramie
# 1746659    NCore - North Cheyenne Soccer Complex  Wyoming   Laramie
# 1746660    NCore - North Cheyenne Soccer Complex  Wyoming   Laramie
#
#                   City Date Local          NO2 Units  ...          SO2 Units  \
# 0              Phoenix 2000-01-01  Parts per billion  ...  Parts per billion
# 1              Phoenix 2000-01-01  Parts per billion  ...  Parts per billion
# 2              Phoenix 2000-01-01  Parts per billion  ...  Parts per billion
# 3              Phoenix 2000-01-01  Parts per billion  ...  Parts per billion
# 4              Phoenix 2000-01-02  Parts per billion  ...  Parts per billion
# ...                ...        ...                ...  ...                ...
# 1746656  Not in a city 2016-03-30  Parts per billion  ...  Parts per billion
# 1746657  Not in a city 2016-03-31  Parts per billion  ...  Parts per billion
# 1746658  Not in a city 2016-03-31  Parts per billion  ...  Parts per billion
# 1746659  Not in a city 2016-03-31  Parts per billion  ...  Parts per billion
# 1746660  Not in a city 2016-03-31  Parts per billion  ...  Parts per billion
#
#          SO2 Mean  SO2 1st Max Value  SO2 1st Max Hour SO2 AQI  \
# 0        3.000000                9.0                21    13.0
# 1        3.000000                9.0                21    13.0
# 2        2.975000                6.6                23     NaN
# 3        2.975000                6.6                23     NaN
# 4        1.958333                3.0                22     4.0
# ...           ...                ...               ...     ...
# 1746656  0.000000                0.0                 2     NaN
# 1746657 -0.022727                0.0                 0     0.0
# 1746658 -0.022727                0.0                 0     0.0
# 1746659  0.000000                0.0                 5     NaN
# 1746660  0.000000                0.0                 5     NaN
#
#                   CO Units   CO Mean  CO 1st Max Value  CO 1st Max Hour CO AQI
# 0        Parts per million  1.145833             4.200               21    NaN
# 1        Parts per million  0.878947             2.200               23   25.0
# 2        Parts per million  1.145833             4.200               21    NaN
# 3        Parts per million  0.878947             2.200               23   25.0
# 4        Parts per million  0.850000             1.600               23    NaN
# ...                    ...       ...               ...              ...    ...
# 1746656  Parts per million  0.091667             0.100                2    1.0
# 1746657  Parts per million  0.067714             0.127                0    NaN
# 1746658  Parts per million  0.100000             0.100                0    1.0
# 1746659  Parts per million  0.067714             0.127                0    NaN
# 1746660  Parts per million  0.100000             0.100                0    1.0
#
# [1746661 rows x 29 columns]

# %%
df2 = df.drop(['Unnamed: 0', 'County Code', 'Site Num', 'Address', 'State', 'NO2 Units', 'NO2 1st Max Value',
              'NO2 1st Max Hour', 'O3 Units', 'O3 1st Max Value', 'O3 1st Max Hour', 'SO2 Units',
              'SO2 1st Max Value', 'SO2 1st Max Hour', 'CO Units', 'CO 1st Max Value', 'CO 1st Max Hour'], axis=1)
df2
# Out:
#          State Code    County           City Date Local   NO2 Mean  NO2 AQI  \
# 0                 4  Maricopa        Phoenix 2000-01-01  19.041667       46
# 1                 4  Maricopa        Phoenix 2000-01-01  19.041667       46
# 2                 4  Maricopa        Phoenix 2000-01-01  19.041667       46
# 3                 4  Maricopa        Phoenix 2000-01-01  19.041667       46
# 4                 4  Maricopa        Phoenix 2000-01-02  22.958333       34
# ...             ...       ...            ...        ...        ...      ...
# 1746656          56   Laramie  Not in a city 2016-03-30   1.083333        1
# 1746657          56   Laramie  Not in a city 2016-03-31   0.939130        1
# 1746658          56   Laramie  Not in a city 2016-03-31   0.939130        1
# 1746659          56   Laramie  Not in a city 2016-03-31   0.939130        1
# 1746660          56   Laramie  Not in a city 2016-03-31   0.939130        1
#
#           O3 Mean  O3 AQI  SO2 Mean  SO2 AQI   CO Mean  CO AQI
# 0        0.022500      34  3.000000     13.0  1.145833     NaN
# 1        0.022500      34  3.000000     13.0  0.878947    25.0
# 2        0.022500      34  2.975000      NaN  1.145833     NaN
# 3        0.022500      34  2.975000      NaN  0.878947    25.0
# 4        0.013375      27  1.958333      4.0  0.850000     NaN
# ...           ...     ...       ...      ...       ...     ...
# 1746656  0.043917      44  0.000000      NaN  0.091667     1.0
# 1746657  0.045263      44 -0.022727      0.0  0.067714     NaN
# 1746658  0.045263      44 -0.022727      0.0  0.100000     1.0
# 1746659  0.045263      44  0.000000      NaN  0.067714     NaN
# 1746660  0.045263      44  0.000000      NaN  0.100000     1.0
#
# [1746661 rows x 12 columns]

# %%
df['County Code'].value_counts()
# Out:
# 13     149210
# 37      95231
# 83      82998
# 1       79528
# 3       68119
#         ...
# 145      1426
# 127      1404
# 55       1164
# 121       964
# 191       946
# Name: County Code, Length: 73, dtype: int64

# %%
df['City'].value_counts()
# Out:
# Not in a city         138411
# New York               46887
# Los Angeles            42241
# Phoenix                37912
# El Paso                36908
#                        ...
# St. Ann                  860
# Kenner                   544
# Bakersfield              434
# Dentsville (Dents)       116
# Roosevelt                104
# Name: City, Length: 144, dtype: int64

# %%
dfcc13 = df.loc[(df['County Code'] == 13)]

# %%
dfcc13['City'].value_counts()
# Out:
# Phoenix          37912
# Concord          23686
# Bethel Island    23396
# San Pablo        21960
# Pittsburg        13076
# Newark            9534
# Scottsdale        8674
# Altoona           7580
# Crockett          1892
# Riverton          1396
# Roosevelt          104
# Name: City, dtype: int64

# %%
df['City'].value_counts()
# Out:
# Not in a city         138411
# New York               46887
# Los Angeles            42241
# Phoenix                37912
# El Paso                36908
#                        ...
# St. Ann                  860
# Kenner                   544
# Bakersfield              434
# Dentsville (Dents)       116
# Roosevelt                104
# Name: City, Length: 144, dtype: int64

# %%
dfx = df2.drop(['SO2 AQI', 'CO AQI'], axis=1)

# %%
X = dfx.drop(['NO2 AQI'], axis=1)
y = dfx['NO2 AQI']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
cols_encode = ['County', 'City']
ohe = OneHotEncoder(sparse=False, handle_unknown='ignore')
ohe_fit = ohe.fit_transform(X_train[cols_encode])
ohe_df = pd.DataFrame(ohe_fit, columns=ohe.get_feature_names(cols_encode), index=X_train.index)

# %%
ohe_df
# Out:
#          County_Ada  County_Adair  County_Adams  County_Alameda  \
# 913604          1.0           0.0           0.0             0.0
# 1472046         0.0           0.0           0.0             0.0
# 662103          0.0           0.0           0.0             0.0
# 1667661         0.0           0.0           0.0             0.0
# 413828          0.0           0.0           0.0             0.0
# ...             ...           ...           ...             ...
# 259178          0.0           0.0           0.0             0.0
# 1414414         0.0           0.0           0.0             0.0
# 131932          0.0           0.0           0.0             0.0
# 671155          0.0           0.0           0.0             0.0
# 121958          0.0           0.0           0.0             0.0
#
#          County_Alexandria City  County_Allegheny  County_Anoka  \
# 913604                      0.0               0.0           0.0
# 1472046                     0.0               0.0           0.0
# 662103                      0.0               0.0           0.0
# 1667661                     0.0               0.0           0.0
# 413828                      0.0               0.0           0.0
# ...                         ...               ...           ...
# 259178                      0.0               0.0           0.0
# 1414414                     0.0               0.0           0.0
# 131932                      0.0               0.0           0.0
# 671155                      0.0               0.0           0.0
# 121958                      0.0               0.0           0.0
#
#          County_Aroostook  County_Athens  County_BAJA CALIFORNIA NORTE  ...  \
# 913604                0.0            0.0                           0.0  ...
# 1472046               0.0            0.0                           0.0  ...
# 662103                0.0            0.0                           0.0  ...
# 1667661               1.0            0.0                           0.0  ...
# 413828                0.0            0.0                           0.0  ...
# ...                   ...            ...                           ...  ...
# 259178                0.0            0.0                           0.0  ...
# 1414414               0.0            0.0                           0.0  ...
# 131932                0.0            0.0                           0.0  ...
# 671155                0.0            0.0                           0.0  ...
# 121958                0.0            0.0                           0.0  ...
#
#          City_Waco  City_Washington  City_Welby  City_West Los Angeles  \
# 913604         0.0              0.0         0.0                    0.0
# 1472046        0.0              0.0         0.0                    0.0
# 662103         0.0              0.0         0.0                    0.0
# 1667661        0.0              0.0         0.0                    0.0
# 413828         0.0              0.0         0.0                    0.0
# ...            ...              ...         ...                    ...
# 259178         0.0              0.0         0.0                    0.0
# 1414414        0.0              0.0         0.0                    0.0
# 131932         0.0              0.0         0.0                    0.0
# 671155         0.0              0.0         0.0                    0.0
# 121958         0.0              0.0         0.0                    0.0
#
#          City_Westport  City_Wilkes-Barre  City_Wilmington  \
# 913604             0.0                0.0              0.0
# 1472046            0.0                0.0              0.0
# 662103             0.0                0.0              0.0
# 1667661            0.0                0.0              0.0
# 413828             0.0                0.0              0.0
# ...                ...                ...              ...
# 259178             0.0                0.0              0.0
# 1414414            0.0                0.0              0.0
# 131932             0.0                0.0              0.0
# 671155             0.0                0.0              0.0
# 121958             0.0                0.0              0.0
#
#          City_Winston-Salem  City_Winter Park  City_York
# 913604                  0.0               0.0        0.0
# 1472046                 0.0               0.0        0.0
# 662103                  0.0               0.0        0.0
# 1667661                 0.0               0.0        0.0
# 413828                  0.0               0.0        0.0
# ...                     ...               ...        ...
# 259178                  0.0               0.0        0.0
# 1414414                 0.0               0.0        0.0
# 131932                  0.0               0.0        0.0
# 671155                  0.0               0.0        0.0
# 121958                  0.0               0.0        0.0
#
# [1309995 rows x 277 columns]

# %%
X_train_int = X_train.drop(cols_encode, axis=1)
X_train_fin = pd.concat((X_train_int, ohe_df), axis=1)
X_train_fin
# Out:
#          State Code Date Local   NO2 Mean   O3 Mean  O3 AQI  SO2 Mean  \
# 913604           16 2009-06-02   4.250000  0.026458      31  0.137500
# 1472046           5 2014-04-20  10.625000  0.040417      64  1.637500
# 662103            6 2007-04-19  12.090909  0.030833      29  0.454545
# 1667661          23 2015-12-27   1.595833  0.027684      26  0.400000
# 413828           29 2004-09-15  11.750000  0.020708      28  6.041667
# ...             ...        ...        ...       ...     ...       ...
# 259178           42 2002-10-07   9.666667  0.024208      26  5.125000
# 1414414          35 2013-07-27   5.250000  0.051667      71  0.600000
# 131932            6 2001-08-12   7.173913  0.021500      31  9.214286
# 671155            6 2007-07-08   3.826087  0.025917      26  0.657143
# 121958            6 2001-06-30   8.652174  0.025000      23  1.000000
#
#           CO Mean  County_Ada  County_Adair  County_Adams  ...  City_Waco  \
# 913604   0.100000         1.0           0.0           0.0  ...        0.0
# 1472046  0.250833         0.0           0.0           0.0  ...        0.0
# 662103   0.429167         0.0           0.0           0.0  ...        0.0
# 1667661  0.154083         0.0           0.0           0.0  ...        0.0
# 413828   0.537500         0.0           0.0           0.0  ...        0.0
# ...           ...         ...           ...           ...  ...        ...
# 259178   0.000000         0.0           0.0           0.0  ...        0.0
# 1414414  0.105125         0.0           0.0           0.0  ...        0.0
# 131932   0.087500         0.0           0.0           0.0  ...        0.0
# 671155   0.300000         0.0           0.0           0.0  ...        0.0
# 121958   0.504167         0.0           0.0           0.0  ...        0.0
#
#          City_Washington  City_Welby  City_West Los Angeles  City_Westport  \
# 913604               0.0         0.0                    0.0            0.0
# 1472046              0.0         0.0                    0.0            0.0
# 662103               0.0         0.0                    0.0            0.0
# 1667661              0.0         0.0                    0.0            0.0
# 413828               0.0         0.0                    0.0            0.0
# ...                  ...         ...                    ...            ...
# 259178               0.0         0.0                    0.0            0.0
# 1414414              0.0         0.0                    0.0            0.0
# 131932               0.0         0.0                    0.0            0.0
# 671155               0.0         0.0                    0.0            0.0
# 121958               0.0         0.0                    0.0            0.0
#
#          City_Wilkes-Barre  City_Wilmington  City_Winston-Salem  \
# 913604                 0.0              0.0                 0.0
# 1472046                0.0              0.0                 0.0
# 662103                 0.0              0.0                 0.0
# 1667661                0.0              0.0                 0.0
# 413828                 0.0              0.0                 0.0
# ...                    ...              ...                 ...
# 259178                 0.0              0.0                 0.0
# 1414414                0.0              0.0                 0.0
# 131932                 0.0              0.0                 0.0
# 671155                 0.0              0.0                 0.0
# 121958                 0.0              0.0                 0.0
#
#          City_Winter Park  City_York
# 913604                0.0        0.0
# 1472046               0.0        0.0
# 662103                0.0        0.0
# 1667661               0.0        0.0
# 413828                0.0        0.0
# ...                   ...        ...
# 259178                0.0        0.0
# 1414414               0.0        0.0
# 131932                0.0        0.0
# 671155                0.0        0.0
# 121958                0.0        0.0
#
# [1309995 rows x 284 columns]

# %%
from sklearn.dummy import DummyRegressor
from sklearn.metrics import mean_squared_error as mse


dummy = DummyRegressor()
dummy.fit(X_train_fin, y_train)
yb_hat_train = dummy.predict(X_train_fin)
yb_hat_test = dummy.predict(X_test)
trainb_rmse = mse(y_train, yb_hat_train, squared=False)
testb_rmse = mse(y_test, yb_hat_test, squared=False)
print(trainb_rmse, testb_rmse)
# Out:
# 15.16506747704698 15.156006443352808

# %%
X_train_temp = X_train_fin.copy()

# %%
X_train_temp['Date'] = X_train_temp['Date Local'].dt.day
X_train_temp['Month'] = X_train_temp['Date Local'].dt.month
X_train_temp['Year'] = X_train_temp['Date Local'].dt.year

# %%
X_train_temp.drop('Date Local', axis=1, inplace=True)

# %%
X_train_temp
# Out:
#          State Code   NO2 Mean   O3 Mean  O3 AQI  SO2 Mean   CO Mean  \
# 913604           16   4.250000  0.026458      31  0.137500  0.100000
# 1472046           5  10.625000  0.040417      64  1.637500  0.250833
# 662103            6  12.090909  0.030833      29  0.454545  0.429167
# 1667661          23   1.595833  0.027684      26  0.400000  0.154083
# 413828           29  11.750000  0.020708      28  6.041667  0.537500
# ...             ...        ...       ...     ...       ...       ...
# 259178           42   9.666667  0.024208      26  5.125000  0.000000
# 1414414          35   5.250000  0.051667      71  0.600000  0.105125
# 131932            6   7.173913  0.021500      31  9.214286  0.087500
# 671155            6   3.826087  0.025917      26  0.657143  0.300000
# 121958            6   8.652174  0.025000      23  1.000000  0.504167
#
#          County_Ada  County_Adair  County_Adams  County_Alameda  ...  \
# 913604          1.0           0.0           0.0             0.0  ...
# 1472046         0.0           0.0           0.0             0.0  ...
# 662103          0.0           0.0           0.0             0.0  ...
# 1667661         0.0           0.0           0.0             0.0  ...
# 413828          0.0           0.0           0.0             0.0  ...
# ...             ...           ...           ...             ...  ...
# 259178          0.0           0.0           0.0             0.0  ...
# 1414414         0.0           0.0           0.0             0.0  ...
# 131932          0.0           0.0           0.0             0.0  ...
# 671155          0.0           0.0           0.0             0.0  ...
# 121958          0.0           0.0           0.0             0.0  ...
#
#          City_West Los Angeles  City_Westport  City_Wilkes-Barre  \
# 913604                     0.0            0.0                0.0
# 1472046                    0.0            0.0                0.0
# 662103                     0.0            0.0                0.0
# 1667661                    0.0            0.0                0.0
# 413828                     0.0            0.0                0.0
# ...                        ...            ...                ...
# 259178                     0.0            0.0                0.0
# 1414414                    0.0            0.0                0.0
# 131932                     0.0            0.0                0.0
# 671155                     0.0            0.0                0.0
# 121958                     0.0            0.0                0.0
#
#          City_Wilmington  City_Winston-Salem  City_Winter Park  City_York  \
# 913604               0.0                 0.0               0.0        0.0
# 1472046              0.0                 0.0               0.0        0.0
# 662103               0.0                 0.0               0.0        0.0
# 1667661              0.0                 0.0               0.0        0.0
# 413828               0.0                 0.0               0.0        0.0
# ...                  ...                 ...               ...        ...
# 259178               0.0                 0.0               0.0        0.0
# 1414414              0.0                 0.0               0.0        0.0
# 131932               0.0                 0.0               0.0        0.0
# 671155               0.0                 0.0               0.0        0.0
# 121958               0.0                 0.0               0.0        0.0
#
#          Date  Month  Year
# 913604      2      6  2009
# 1472046    20      4  2014
# 662103     19      4  2007
# 1667661    27     12  2015
# 413828     15      9  2004
# ...       ...    ...   ...
# 259178      7     10  2002
# 1414414    27      7  2013
# 131932     12      8  2001
# 671155      8      7  2007
# 121958     30      6  2001
#
# [1309995 rows x 286 columns]

# %%
X_train_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309995 entries, 913604 to 121958
# Columns: 286 entries, State Code to Year
# dtypes: float64(281), int64(5)
# memory usage: 2.8 GB

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train_temp, y_train)
y1_hat_train = lr.predict(X_train_temp)
#y1_hat_test = lr.predict(X_test)
train1_rmse = mse(y_train, y1_hat_train, squared=False)
#test1_rmse = mse(y_test, y1_hat_test, squared=False)
print(train1_rmse)
# Out:
# 5.7405018231916545

# %%
for state in df['State']:
    print(state)

# %%
state_dict = {}
for state in df['State']:
    if state in state_dict:
        pass
    else:
        state_dict[state] = df['State Code']

# %%
state_dict = []
for item in df['State']:
    if (df['State Code'], df['State']) in state_dict:
        pass
    else:
        state_dict.append((df['State Code'], df['State']))

# %%
df.describe()

# %%
df.isna().sum()

# %%
df.loc[df['Unnamed: 0'] == 2047]

# %%
dfaqi2016 = pd.read_csv('data/daily_aqi_by_cbsa_2016.csv')
dfaqi2016

# %%
dfozone2016 = pd.read_csv('data/daily_44201_2016.csv')

# %%
dfozone2016

# %%
dfozone2016.columns

# %%
dfozone2016.drop(labels=['State Code', 'POC', 'Latitude', 'Longitude', 'Event Type', 'Units of Measure', 'Parameter Code'], axis=1, inplace=True)
dfozone2016

# %%
dfozone2016.columns

# %%
dfozone2016.drop(labels=['Datum', 'County Code', 'Site Num', 'Parameter Name',], axis=1, inplace=True)
dfozone2016

# %%
dfozone2016.drop('Method Name', axis=1, inplace=True)
dfozone2016

# %%
plt.figure(figsize=(20,10))
c = df.corr()
sns.heatmap(c, cmap='BrBG',annot=True);

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe = OneHotEncoder().fit_transform(X)
